# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.arange(1,11)
y = 2*x + 10
plt.title('This is the title of the graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.plot(x, y)
plt.show()
